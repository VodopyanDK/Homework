# %% [markdown]
# # Домашнее задание
#
# ## Задание 1
#
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
import pandas as pd

# %%
movies = pd.read_csv('movies.csv')
ratings = pd.read_csv('ratings.csv')
joined = ratings.merge(movies, on='movieId', how='left')
ratings_5 = joined[ joined.rating == 5 ]
ratings_5['title'].value_counts().head(1)
# Out:
# Shawshank Redemption, The (1994)    39553
# Name: title, dtype: int64

# %% [markdown]
# ## Задание 2
#
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
power = pd.read_csv('power.csv')
print(power[ power['country'].str.contains('lat', case=False) ]['country'].unique(), power[ power['country'].str.contains('lit', case=False) ]['country'].unique(), power[ power['country'].str.contains('est', case=False) ]['country'].unique())
# Out:
# ['Latvia'] ['Lithuania'] ['Estonia' 'State of Palestine' 'Timor-Leste']

# %%
filtered_countries_1 = power[ ((power['country']=='Lithuania') | (power['country']=='Latvia') | \
                               (power['country']=='Estonia')) & ((power['category'] == 4) | \
                                (power['category'] == 12) | (power['category'] == 21)) & \
                            ((power['year'] >= 2005) & (power['year'] <= 2010))]
a = 0
for i in filtered_countries_1.quantity:
    if i > 0:
        a += i
print(a)
# Out:
# 240580.0

# %% [markdown]
# ## Задание 3
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe. Примеры страниц (необязательно брать именно эти): https://fortrader.org/quotes https://www.finanz.ru/valyuty/v-realnom-vremeni

# %%
dataframe = pd.read_html('https://fortrader.org/quotes')

# %%
dataframe[3]
# Out:
#                                         Название      Цена  Изменение  \
# 0                                  ВТБ Акции ВТБ  0.049925   -0.00002
# 1                         Газпром Акции газпрома    282.26   -0.01000
# 2                            Лукойл Акции Лукойл   6 236.0    0.00000
# 3                        Роснефть Акции Роснефти    544.55   -0.35000
# 4                       Сбербанк Акции Сбербанка    319.15    0.00000
# 5           Сургутнефтегаз Акции Сургутнефтегаза    33.400    0.00000
# 6                      Норникель Акции Норникель    25 106    4.00000
# 7                       Аэрофлот Акции Аерофлота     66.86    0.00000
# 8                    Северсталь Акции Северсталь  1 758.60   -1.20000
# 9                    Транснефть Акции Транснефть   158 800 -200.00000
# 10             Ростелеком Курс акций ростелекома     95.65    0.00000
# 11                      РУСАЛ Акции РУСАЛ (RUAL)    51.250    0.00000
# 12      Детский мир iDreamSky Technology Limited    135.48   -0.08000
# 13             Петропавловск Акции Петропавловск     20.56   -0.06000
# 14                    Алроса Акции АЛРОСА (ALRS)   138.710    0.00000
# 15                    Магнит Акции Магнит (MGNT)   5 458.0   -0.50000
# 16                        НМЛК Акции НЛМК (NLMK)   256.020    0.00000
# 17                  М.видео Акции М.видео (MVID)    642.10   -0.40000
# 18    Газпром нефть Акции "Газпром нефть" (SIBN)    426.25   -0.10000
# 19                        НМТП Акции НМТП (NMTP)    7.4250   -0.01000
# 20            Полиметалл Акции Полиметалл (POLY)  1 551.50    0.00000
# 21        Полюс Золото Акции Полюс Золото (PLZL)  13 661.5  -12.50000
# 22                  НОВАТЭК Акции НОВАТЭК (NVTK)  1 667.00   -0.60000
# 23                РусГидро Акции РусГидро (HYDR)    0.8210   -0.00020
# 24                Татнефть Акции Татнефть (TATN)    494.10    0.00000
# 25        АФК Система Акции АФК "Система" (AFKS)    29.572   -0.02000
# 26                                 МТС Акции МТС    316.10    0.00000
# 27                Башнефть Акции Башнефть (BANE)   1 355.0    0.00000
# 28                    Яндекс Акции Яндекс (YNDX)   4 965.4   -5.80000
# 29  X5 Retail Group Акции X5 Retail Group (FIVE)  2 388.00   -0.50000
# 30                  ФСК ЕЭС Акции ФСК ЕЭС (FEES)   0.19688   -0.00012
# 31                      Мечел Акции Мечел (MTLR)     81.29   -0.04000
# 32                МосБиржа Акции МосБиржа (MOEX)    174.50    0.00000
# 33              Интер РАО Акции Интер РАО (IRAO)      4.32   -0.01000
# 34              Mail.ru Акции Mail.ru (MAIL, ДР)  1 505.40   -0.60000
# 35                        Киви Акции Киви (QIWI)     725.0    0.00000
# 36                  Лента Акции Лента (LNTA, ДР)    229.10   -0.10000
# 37            Тинькофф Акции Тинькофф (TCSG, др)  6 749.00    0.00000
# 38                        Озон Акции Озон (Ozon)  3 814.00   -2.50000
#
#     Изменение(%)  Обновлено
# 0      -0.040044        NaN
# 1      -0.000000        NaN
# 2       0.000000        NaN
# 3      -0.060000        NaN
# 4       0.000000        NaN
# 5       0.000000        NaN
# 6       0.000000        NaN
# 7       0.000000        NaN
# 8      -0.070000        NaN
# 9      -0.000000        NaN
# 10      0.000000        NaN
# 11      0.000000        NaN
# 12     -0.060000        NaN
# 13     -0.290000        NaN
# 14      0.000000        NaN
# 15     -0.000000        NaN
# 16      0.000000        NaN
# 17     -0.060000        NaN
# 18     -0.020000        NaN
# 19     -0.134500        NaN
# 20      0.000000        NaN
# 21     -0.100000        NaN
# 22     -0.040000        NaN
# 23     -0.024400        NaN
# 24      0.000000        NaN
# 25     -0.068000        NaN
# 26      0.000000        NaN
# 27      0.000000        NaN
# 28     -0.100000        NaN
# 29     -0.020000        NaN
# 30     -0.060910        NaN
# 31     -0.050000        NaN
# 32      0.000000        NaN
# 33     -0.170000        NaN
# 34     -0.040000        NaN
# 35      0.000000        NaN
# 36     -0.040000        NaN
# 37      0.000000        NaN
# 38     -0.070000        NaN
